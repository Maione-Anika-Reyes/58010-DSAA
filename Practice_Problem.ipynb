# %% [markdown]
# <a href="https://colab.research.google.com/github/Maione-Anika-Reyes/58010-DSAA/blob/main/Practice_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
test_scores = [26, 49, 98, 87, 62, 75]
total = 0

for score in test_scores:
  if score %2 == 0:
    total += score

print("Total of even test scores is:",x)
# Out:
# Total of even test scores is: 186

# %% [markdown]
# ![Practice Problem (Flowchart).png](data:image/png;base64,...)
